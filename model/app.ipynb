# %%
import pandas as pd
import joblib

# Load data
df =  pd.read_csv(r'C:\Users\chach\OneDrive\Documents\try\aicte_internship\week1\data_cleaned.csv')

# Load the model
model = joblib.load(r'C:\Users\chach\OneDrive\Documents\try\aicte_internship\week3\forecasting_co2_emmision.pkl')

# Prepare input features (update these as needed)
# Use only 7 features as expected by the model
X = df[['cereal_yield','fdi_perc_gdp','gni_per_cap', 'en_per_cap',
                'pop_urb_aggl_perc', 'prot_area_perc', 'pop_growth_perc']]

# Predict
predictions = model.predict(X)

# View results
df['Predicted CO2'] = predictions
df.head()
# Out:
# c:\Users\chach\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
#   country  year  cereal_yield  fdi_perc_gdp  en_per_gdp  en_per_cap  \
# 0     AGO  1991         417.4      5.449515  179.271884  565.451027
# 1     AGO  1992         397.0      4.982460  193.632183  550.548264
# 2     AGO  1993         267.8      5.715529  266.318379  551.688878
# 3     AGO  1994         298.4      4.195018  260.830190  541.553067
# 4     AGO  1995         402.2      9.374417  237.623934  528.386164
#
#      co2_ttl  co2_per_cap  co2_per_gdp  pop_urb_aggl_perc  prot_area_perc  \
# 0   4367.397     0.409949   129.971142          15.290728       12.399822
# 1   4418.735     0.401597   141.244823          15.660630       12.399823
# 2   5801.194     0.510141   246.261769          16.025739       12.399823
# 3   3890.687     0.331321   159.575256          16.065941       12.399824
# ...
